# %% [markdown]
# # HYPOTHESIS TESTING SUPERSTORE

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stest

# %%
df = pd.read_csv('Superstore.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#   Country/Region  Postal Code Region       Product ID         Category  \
# 0  United States      42420.0  South  FUR-BO-10001798        Furniture
# 1  United States      42420.0  South  FUR-CH-10000454        Furniture
# 2  United States      90036.0   West  OFF-LA-10000240  Office Supplies
# 3  United States      33311.0  South  FUR-TA-10000577        Furniture
# 4  United States      33311.0  South  OFF-ST-10000760  Office Supplies
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Country/Region  9994 non-null   object
#  7   Postal Code     9983 non-null   float64
#  8   Region          9994 non-null   object
#  9   Product ID      9994 non-null   object
#  10  Category        9994 non-null   object
#  11  Sub-Category    9994 non-null   object
#  12  Product Name    9994 non-null   object
#  13  Sales           9994 non-null   float64
#  14  Quantity        9994 non-null   int64
#  15  Discount        9994 non-null   float64
#  16  Profit          9994 non-null   float64
# ...

# %%
del df['Unnamed: 17']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Country/Region  9994 non-null   object
#  7   Postal Code     9983 non-null   float64
#  8   Region          9994 non-null   object
#  9   Product ID      9994 non-null   object
#  10  Category        9994 non-null   object
#  11  Sub-Category    9994 non-null   object
#  12  Product Name    9994 non-null   object
#  13  Sales           9994 non-null   float64
#  14  Quantity        9994 non-null   int64
#  15  Discount        9994 non-null   float64
#  16  Profit          9994 non-null   float64
# ...

# %% [markdown]
# # Column Quantity dan Profit
#
# H0: Tidak ada perbedaan antara jumlah barang yang dibeli ('Quantity') dan keuntungan ('Profit')
#
# H1: Ada perbedaan antara jumlah barang yang dibeli ('Quantity') dan keuntungan ('Profit')

# %%
df[['Quantity','Profit']].describe()
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#   Country/Region  Postal Code Region       Product ID         Category  \
# 0  United States      42420.0  South  FUR-BO-10001798        Furniture
# 1  United States      42420.0  South  FUR-CH-10000454        Furniture
# 2  United States      90036.0   West  OFF-LA-10000240  Office Supplies
# 3  United States      33311.0  South  FUR-TA-10000577        Furniture
# 4  United States      33311.0  South  OFF-ST-10000760  Office Supplies
#
# ...

# %%
ttest, pval = stats.ttest_rel(df['Quantity'], df['Profit'])
print(pval)
# Out:
# 3.378577057060209e-26

# %%
if pval < alpha:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# Reject null hypothesis

# %% [markdown]
# KESIMPULAN: karena pvalue > 0.05 maka H0 ditolak dan H1 diterima dengan artian lain ada perbedaan antara jumlah barang yang dibeli ('Quantity') dan rata-rata keuntungan ('Profit')

# %% [markdown]
# # Column Quantity dan Discount
#
# H0: Tidak ada perbedaan antara jumlah barang yang dibeli ('Quantity') dan persentase diskon yang diberikan pada pesanan ('Discount')
#
# H1: Ada perbedaan antara jumlah barang yang dibeli ('Quantity') dan persentase diskon yang diberikan pada pesanan ('Discount')

# %%
df[['Quantity','Discount']].describe()
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#   Country/Region  Postal Code Region       Product ID         Category  \
# 0  United States      42420.0  South  FUR-BO-10001798        Furniture
# 1  United States      42420.0  South  FUR-CH-10000454        Furniture
# 2  United States      90036.0   West  OFF-LA-10000240  Office Supplies
# 3  United States      33311.0  South  FUR-TA-10000577        Furniture
# 4  United States      33311.0  South  OFF-ST-10000760  Office Supplies
#
# ...

# %%
ttest, pval1 = stats.ttest_rel(df['Quantity'], df['Discount'])
print(pval1)
# Out:
# 0.0

# %%
if pval1<0.05:
    print("reject null hypothesis")
else:
    print("accpet null hypothesis")
# Out:
# reject null hypothesis

# %% [markdown]
# KESIMPULAN: karena pvalue > 0.05 maka H0 ditolak dan H1 diterima dengan artian lain ada perbedaan antara jumlah barang yang dibeli ('Quantity') dan persentase diskon yang diberikan pada pesanan ('Discount')

# %% [markdown]
# # Column Discount dan Profit
# H0: Tidak ada perbedaan antara discount dan profit
#
# H1: Ada perbedaan antara discount dan profit

# %%
df[['Discount','Profit']].describe()
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#   Country/Region  Postal Code Region       Product ID         Category  \
# 0  United States      42420.0  South  FUR-BO-10001798        Furniture
# 1  United States      42420.0  South  FUR-CH-10000454        Furniture
# 2  United States      90036.0   West  OFF-LA-10000240  Office Supplies
# 3  United States      33311.0  South  FUR-TA-10000577        Furniture
# 4  United States      33311.0  South  OFF-ST-10000760  Office Supplies
#
# ...

# %%
ttest, pval2 = stats.ttest_rel(df['Discount'], df['Profit'])
print(pval2)
# Out:
# 8.76197080469636e-34

# %%
if pval2<0.05:
    print("reject null hypothesis")
else:
    print("accpet null hypothesis")
# Out:
# reject null hypothesis

# %% [markdown]
# KESIMPULAN: karena pvalue > 0.05 maka H0 ditolak dan H1 diterima dengan artian lain ada perbedaan antara discount dan profit

# %% [markdown]
# # Column Sales dan Profit
# H0: Tidak ada perbedaan antara total penjualan(sales) dan profit
#
# H1: Ada perbedaan antara total penjualan(sales) dan profit

# %%
df[['Sales','Profit']].describe()
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#   Country/Region  Postal Code Region       Product ID         Category  \
# 0  United States      42420.0  South  FUR-BO-10001798        Furniture
# 1  United States      42420.0  South  FUR-CH-10000454        Furniture
# 2  United States      90036.0   West  OFF-LA-10000240  Office Supplies
# 3  United States      33311.0  South  FUR-TA-10000577        Furniture
# 4  United States      33311.0  South  OFF-ST-10000760  Office Supplies
#
# ...

# %%
ttest, pval3 = stats.ttest_rel(df['Sales'], df['Profit'])
print(pval3)
# Out:
# 3.8264152172677997e-274

# %%
if pval3<0.05:
    print("reject null hypothesis")
else:
    print("accpet null hypothesis")
# Out:
# reject null hypothesis

# %% [markdown]
# KESIMPULAN: karena pvalue > 0.05 maka H0 ditolak dan H1 diterima dengan artian lain ada perbedaan antara total penjualan(sales) dan profit
